# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
import xml.etree.ElementTree as xet
from glob import glob

# %% [markdown]
# ## Data Preparation

# %%
path = glob('./lpd_dataset_v2/*.xml')
path
# Out:
# ['./lpd_dataset_v2\\lpd_image (1).xml',
#  './lpd_dataset_v2\\lpd_image (10).xml',
#  './lpd_dataset_v2\\lpd_image (100).xml',
#  './lpd_dataset_v2\\lpd_image (1000).xml',
#  './lpd_dataset_v2\\lpd_image (101).xml',
#  './lpd_dataset_v2\\lpd_image (102).xml',
#  './lpd_dataset_v2\\lpd_image (103).xml',
#  './lpd_dataset_v2\\lpd_image (104).xml',
#  './lpd_dataset_v2\\lpd_image (105).xml',
#  './lpd_dataset_v2\\lpd_image (106).xml',
#  './lpd_dataset_v2\\lpd_image (107).xml',
#  './lpd_dataset_v2\\lpd_image (108).xml',
#  './lpd_dataset_v2\\lpd_image (109).xml',
#  './lpd_dataset_v2\\lpd_image (11).xml',
#  './lpd_dataset_v2\\lpd_image (110).xml',
#  './lpd_dataset_v2\\lpd_image (111).xml',
#  './lpd_dataset_v2\\lpd_image (112).xml',
#  './lpd_dataset_v2\\lpd_image (113).xml',
#  './lpd_dataset_v2\\lpd_image (114).xml',
#  './lpd_dataset_v2\\lpd_image (115).xml',
#  './lpd_dataset_v2\\lpd_image (116).xml',
#  './lpd_dataset_v2\\lpd_image (117).xml',
#  './lpd_dataset_v2\\lpd_image (118).xml',
#  './lpd_dataset_v2\\lpd_image (119).xml',
#  './lpd_dataset_v2\\lpd_image (12).xml',
#  './lpd_dataset_v2\\lpd_image (120).xml',
#  './lpd_dataset_v2\\lpd_image (121).xml',
#  './lpd_dataset_v2\\lpd_image (122).xml',
#  './lpd_dataset_v2\\lpd_image (123).xml',
#  './lpd_dataset_v2\\lpd_image (124).xml',
#  './lpd_dataset_v2\\lpd_image (125).xml',
#  './lpd_dataset_v2\\lpd_image (126).xml',
#  './lpd_dataset_v2\\lpd_image (127).xml',
#  './lpd_dataset_v2\\lpd_image (128).xml',
#  './lpd_dataset_v2\\lpd_image (129).xml',
#  './lpd_dataset_v2\\lpd_image (13).xml',
#  './lpd_dataset_v2\\lpd_image (130).xml',
#  './lpd_dataset_v2\\lpd_image (131).xml',
#  './lpd_dataset_v2\\lpd_image (132).xml',
#  './lpd_dataset_v2\\lpd_image (133).xml',
#  './lpd_dataset_v2\\lpd_image (134).xml',
#  './lpd_dataset_v2\\lpd_image (135).xml',
#  './lpd_dataset_v2\\lpd_image (136).xml',
#  './lpd_dataset_v2\\lpd_image (137).xml',
#  './lpd_dataset_v2\\lpd_image (138).xml',
#  './lpd_dataset_v2\\lpd_image (139).xml',
#  './lpd_dataset_v2\\lpd_image (14).xml',
#  './lpd_dataset_v2\\lpd_image (140).xml',
#  './lpd_dataset_v2\\lpd_image (141).xml',
#  './lpd_dataset_v2\\lpd_image (142).xml',
#  './lpd_dataset_v2\\lpd_image (143).xml',
#  './lpd_dataset_v2\\lpd_image (144).xml',
#  './lpd_dataset_v2\\lpd_image (145).xml',
#  './lpd_dataset_v2\\lpd_image (146).xml',
#  './lpd_dataset_v2\\lpd_image (147).xml',
#  './lpd_dataset_v2\\lpd_image (148).xml',
#  './lpd_dataset_v2\\lpd_image (149).xml',
#  './lpd_dataset_v2\\lpd_image (15).xml',
#  './lpd_dataset_v2\\lpd_image (150).xml',
#  './lpd_dataset_v2\\lpd_image (151).xml',
#  './lpd_dataset_v2\\lpd_image (152).xml',
#  './lpd_dataset_v2\\lpd_image (153).xml',
#  './lpd_dataset_v2\\lpd_image (154).xml',
#  './lpd_dataset_v2\\lpd_image (155).xml',
#  './lpd_dataset_v2\\lpd_image (156).xml',
#  './lpd_dataset_v2\\lpd_image (157).xml',
#  './lpd_dataset_v2\\lpd_image (158).xml',
#  './lpd_dataset_v2\\lpd_image (159).xml',
#  './lpd_dataset_v2\\lpd_image (16).xml',
#  './lpd_dataset_v2\\lpd_image (160).xml',
#  './lpd_dataset_v2\\lpd_image (161).xml',
#  './lpd_dataset_v2\\lpd_image (162).xml',
#  './lpd_dataset_v2\\lpd_image (163).xml',
#  './lpd_dataset_v2\\lpd_image (164).xml',
#  './lpd_dataset_v2\\lpd_image (165).xml',
#  './lpd_dataset_v2\\lpd_image (166).xml',
#  './lpd_dataset_v2\\lpd_image (167).xml',
#  './lpd_dataset_v2\\lpd_image (168).xml',
#  './lpd_dataset_v2\\lpd_image (169).xml',
#  './lpd_dataset_v2\\lpd_image (17).xml',
#  './lpd_dataset_v2\\lpd_image (170).xml',
#  './lpd_dataset_v2\\lpd_image (171).xml',
#  './lpd_dataset_v2\\lpd_image (172).xml',
#  './lpd_dataset_v2\\lpd_image (173).xml',
#  './lpd_dataset_v2\\lpd_image (174).xml',
#  './lpd_dataset_v2\\lpd_image (175).xml',
#  './lpd_dataset_v2\\lpd_image (176).xml',
#  './lpd_dataset_v2\\lpd_image (177).xml',
#  './lpd_dataset_v2\\lpd_image (178).xml',
#  './lpd_dataset_v2\\lpd_image (179).xml',
#  './lpd_dataset_v2\\lpd_image (18).xml',
#  './lpd_dataset_v2\\lpd_image (180).xml',
#  './lpd_dataset_v2\\lpd_image (181).xml',
#  './lpd_dataset_v2\\lpd_image (182).xml',
#  './lpd_dataset_v2\\lpd_image (183).xml',
#  './lpd_dataset_v2\\lpd_image (184).xml',
#  './lpd_dataset_v2\\lpd_image (185).xml',
#  './lpd_dataset_v2\\lpd_image (186).xml',
#  './lpd_dataset_v2\\lpd_image (187).xml',
#  './lpd_dataset_v2\\lpd_image (188).xml',
#  './lpd_dataset_v2\\lpd_image (189).xml',
#  './lpd_dataset_v2\\lpd_image (19).xml',
#  './lpd_dataset_v2\\lpd_image (190).xml',
#  './lpd_dataset_v2\\lpd_image (191).xml',
#  './lpd_dataset_v2\\lpd_image (192).xml',
#  './lpd_dataset_v2\\lpd_image (193).xml',
#  './lpd_dataset_v2\\lpd_image (194).xml',
#  './lpd_dataset_v2\\lpd_image (195).xml',
#  './lpd_dataset_v2\\lpd_image (196).xml',
#  './lpd_dataset_v2\\lpd_image (197).xml',
#  './lpd_dataset_v2\\lpd_image (198).xml',
#  './lpd_dataset_v2\\lpd_image (199).xml',
#  './lpd_dataset_v2\\lpd_image (2).xml',
#  './lpd_dataset_v2\\lpd_image (20).xml',
#  './lpd_dataset_v2\\lpd_image (200).xml',
#  './lpd_dataset_v2\\lpd_image (201).xml',
#  './lpd_dataset_v2\\lpd_image (202).xml',
#  './lpd_dataset_v2\\lpd_image (203).xml',
#  './lpd_dataset_v2\\lpd_image (204).xml',
#  './lpd_dataset_v2\\lpd_image (205).xml',
#  './lpd_dataset_v2\\lpd_image (206).xml',
#  './lpd_dataset_v2\\lpd_image (207).xml',
#  './lpd_dataset_v2\\lpd_image (208).xml',
#  './lpd_dataset_v2\\lpd_image (209).xml',
#  './lpd_dataset_v2\\lpd_image (21).xml',
#  './lpd_dataset_v2\\lpd_image (210).xml',
#  './lpd_dataset_v2\\lpd_image (211).xml',
#  './lpd_dataset_v2\\lpd_image (212).xml',
#  './lpd_dataset_v2\\lpd_image (213).xml',
#  './lpd_dataset_v2\\lpd_image (214).xml',
#  './lpd_dataset_v2\\lpd_image (215).xml',
#  './lpd_dataset_v2\\lpd_image (216).xml',
#  './lpd_dataset_v2\\lpd_image (217).xml',
#  './lpd_dataset_v2\\lpd_image (218).xml',
#  './lpd_dataset_v2\\lpd_image (219).xml',
#  './lpd_dataset_v2\\lpd_image (22).xml',
#  './lpd_dataset_v2\\lpd_image (220).xml',
#  './lpd_dataset_v2\\lpd_image (221).xml',
#  './lpd_dataset_v2\\lpd_image (222).xml',
#  './lpd_dataset_v2\\lpd_image (223).xml',
#  './lpd_dataset_v2\\lpd_image (224).xml',
#  './lpd_dataset_v2\\lpd_image (225).xml',
#  './lpd_dataset_v2\\lpd_image (226).xml',
#  './lpd_dataset_v2\\lpd_image (227).xml',
#  './lpd_dataset_v2\\lpd_image (228).xml',
#  './lpd_dataset_v2\\lpd_image (229).xml',
#  './lpd_dataset_v2\\lpd_image (23).xml',
#  './lpd_dataset_v2\\lpd_image (230).xml',
#  './lpd_dataset_v2\\lpd_image (231).xml',
#  './lpd_dataset_v2\\lpd_image (232).xml',
#  './lpd_dataset_v2\\lpd_image (233).xml',
#  './lpd_dataset_v2\\lpd_image (234).xml',
#  './lpd_dataset_v2\\lpd_image (235).xml',
#  './lpd_dataset_v2\\lpd_image (236).xml',
#  './lpd_dataset_v2\\lpd_image (237).xml',
#  './lpd_dataset_v2\\lpd_image (238).xml',
#  './lpd_dataset_v2\\lpd_image (239).xml',
#  './lpd_dataset_v2\\lpd_image (24).xml',
#  './lpd_dataset_v2\\lpd_image (240).xml',
#  './lpd_dataset_v2\\lpd_image (241).xml',
#  './lpd_dataset_v2\\lpd_image (242).xml',
#  './lpd_dataset_v2\\lpd_image (243).xml',
#  './lpd_dataset_v2\\lpd_image (244).xml',
#  './lpd_dataset_v2\\lpd_image (245).xml',
#  './lpd_dataset_v2\\lpd_image (246).xml',
#  './lpd_dataset_v2\\lpd_image (247).xml',
#  './lpd_dataset_v2\\lpd_image (248).xml',
#  './lpd_dataset_v2\\lpd_image (249).xml',
#  './lpd_dataset_v2\\lpd_image (25).xml',
#  './lpd_dataset_v2\\lpd_image (250).xml',
#  './lpd_dataset_v2\\lpd_image (251).xml',
#  './lpd_dataset_v2\\lpd_image (252).xml',
#  './lpd_dataset_v2\\lpd_image (253).xml',
#  './lpd_dataset_v2\\lpd_image (254).xml',
#  './lpd_dataset_v2\\lpd_image (255).xml',
#  './lpd_dataset_v2\\lpd_image (256).xml',
#  './lpd_dataset_v2\\lpd_image (257).xml',
#  './lpd_dataset_v2\\lpd_image (258).xml',
#  './lpd_dataset_v2\\lpd_image (259).xml',
#  './lpd_dataset_v2\\lpd_image (26).xml',
#  './lpd_dataset_v2\\lpd_image (260).xml',
#  './lpd_dataset_v2\\lpd_image (261).xml',
#  './lpd_dataset_v2\\lpd_image (262).xml',
#  './lpd_dataset_v2\\lpd_image (263).xml',
#  './lpd_dataset_v2\\lpd_image (264).xml',
#  './lpd_dataset_v2\\lpd_image (265).xml',
#  './lpd_dataset_v2\\lpd_image (266).xml',
#  './lpd_dataset_v2\\lpd_image (267).xml',
#  './lpd_dataset_v2\\lpd_image (268).xml',
#  './lpd_dataset_v2\\lpd_image (269).xml',
#  './lpd_dataset_v2\\lpd_image (27).xml',
#  './lpd_dataset_v2\\lpd_image (270).xml',
#  './lpd_dataset_v2\\lpd_image (271).xml',
#  './lpd_dataset_v2\\lpd_image (272).xml',
#  './lpd_dataset_v2\\lpd_image (273).xml',
#  './lpd_dataset_v2\\lpd_image (274).xml',
#  './lpd_dataset_v2\\lpd_image (275).xml',
#  './lpd_dataset_v2\\lpd_image (276).xml',
#  './lpd_dataset_v2\\lpd_image (277).xml',
#  './lpd_dataset_v2\\lpd_image (278).xml',
#  './lpd_dataset_v2\\lpd_image (279).xml',
#  './lpd_dataset_v2\\lpd_image (28).xml',
#  './lpd_dataset_v2\\lpd_image (280).xml',
#  './lpd_dataset_v2\\lpd_image (281).xml',
#  './lpd_dataset_v2\\lpd_image (282).xml',
#  './lpd_dataset_v2\\lpd_image (283).xml',
#  './lpd_dataset_v2\\lpd_image (284).xml',
#  './lpd_dataset_v2\\lpd_image (285).xml',
#  './lpd_dataset_v2\\lpd_image (286).xml',
#  './lpd_dataset_v2\\lpd_image (287).xml',
#  './lpd_dataset_v2\\lpd_image (288).xml',
#  './lpd_dataset_v2\\lpd_image (289).xml',
#  './lpd_dataset_v2\\lpd_image (29).xml',
#  './lpd_dataset_v2\\lpd_image (290).xml',
#  './lpd_dataset_v2\\lpd_image (291).xml',
#  './lpd_dataset_v2\\lpd_image (292).xml',
#  './lpd_dataset_v2\\lpd_image (293).xml',
#  './lpd_dataset_v2\\lpd_image (294).xml',
#  './lpd_dataset_v2\\lpd_image (295).xml',
#  './lpd_dataset_v2\\lpd_image (296).xml',
#  './lpd_dataset_v2\\lpd_image (297).xml',
#  './lpd_dataset_v2\\lpd_image (298).xml',
#  './lpd_dataset_v2\\lpd_image (299).xml',
#  './lpd_dataset_v2\\lpd_image (3).xml',
#  './lpd_dataset_v2\\lpd_image (30).xml',
#  './lpd_dataset_v2\\lpd_image (300).xml',
#  './lpd_dataset_v2\\lpd_image (301).xml',
#  './lpd_dataset_v2\\lpd_image (302).xml',
#  './lpd_dataset_v2\\lpd_image (303).xml',
#  './lpd_dataset_v2\\lpd_image (304).xml',
#  './lpd_dataset_v2\\lpd_image (305).xml',
#  './lpd_dataset_v2\\lpd_image (306).xml',
#  './lpd_dataset_v2\\lpd_image (307).xml',
#  './lpd_dataset_v2\\lpd_image (308).xml',
#  './lpd_dataset_v2\\lpd_image (309).xml',
#  './lpd_dataset_v2\\lpd_image (31).xml',
#  './lpd_dataset_v2\\lpd_image (310).xml',
#  './lpd_dataset_v2\\lpd_image (311).xml',
#  './lpd_dataset_v2\\lpd_image (312).xml',
#  './lpd_dataset_v2\\lpd_image (313).xml',
#  './lpd_dataset_v2\\lpd_image (314).xml',
#  './lpd_dataset_v2\\lpd_image (315).xml',
#  './lpd_dataset_v2\\lpd_image (316).xml',
#  './lpd_dataset_v2\\lpd_image (317).xml',
#  './lpd_dataset_v2\\lpd_image (318).xml',
#  './lpd_dataset_v2\\lpd_image (319).xml',
#  './lpd_dataset_v2\\lpd_image (32).xml',
#  './lpd_dataset_v2\\lpd_image (320).xml',
#  './lpd_dataset_v2\\lpd_image (321).xml',
#  './lpd_dataset_v2\\lpd_image (322).xml',
#  './lpd_dataset_v2\\lpd_image (323).xml',
#  './lpd_dataset_v2\\lpd_image (324).xml',
#  './lpd_dataset_v2\\lpd_image (325).xml',
#  './lpd_dataset_v2\\lpd_image (326).xml',
#  './lpd_dataset_v2\\lpd_image (327).xml',
#  './lpd_dataset_v2\\lpd_image (328).xml',
#  './lpd_dataset_v2\\lpd_image (329).xml',
#  './lpd_dataset_v2\\lpd_image (33).xml',
#  './lpd_dataset_v2\\lpd_image (330).xml',
#  './lpd_dataset_v2\\lpd_image (331).xml',
#  './lpd_dataset_v2\\lpd_image (332).xml',
#  './lpd_dataset_v2\\lpd_image (333).xml',
#  './lpd_dataset_v2\\lpd_image (334).xml',
#  './lpd_dataset_v2\\lpd_image (335).xml',
#  './lpd_dataset_v2\\lpd_image (336).xml',
#  './lpd_dataset_v2\\lpd_image (337).xml',
#  './lpd_dataset_v2\\lpd_image (338).xml',
#  './lpd_dataset_v2\\lpd_image (339).xml',
#  './lpd_dataset_v2\\lpd_image (34).xml',
#  './lpd_dataset_v2\\lpd_image (340).xml',
#  './lpd_dataset_v2\\lpd_image (341).xml',
#  './lpd_dataset_v2\\lpd_image (342).xml',
#  './lpd_dataset_v2\\lpd_image (343).xml',
#  './lpd_dataset_v2\\lpd_image (344).xml',
#  './lpd_dataset_v2\\lpd_image (345).xml',
#  './lpd_dataset_v2\\lpd_image (346).xml',
#  './lpd_dataset_v2\\lpd_image (347).xml',
#  './lpd_dataset_v2\\lpd_image (348).xml',
#  './lpd_dataset_v2\\lpd_image (349).xml',
#  './lpd_dataset_v2\\lpd_image (35).xml',
#  './lpd_dataset_v2\\lpd_image (350).xml',
#  './lpd_dataset_v2\\lpd_image (351).xml',
#  './lpd_dataset_v2\\lpd_image (352).xml',
#  './lpd_dataset_v2\\lpd_image (353).xml',
#  './lpd_dataset_v2\\lpd_image (354).xml',
#  './lpd_dataset_v2\\lpd_image (355).xml',
#  './lpd_dataset_v2\\lpd_image (356).xml',
#  './lpd_dataset_v2\\lpd_image (357).xml',
#  './lpd_dataset_v2\\lpd_image (358).xml',
#  './lpd_dataset_v2\\lpd_image (359).xml',
#  './lpd_dataset_v2\\lpd_image (36).xml',
#  './lpd_dataset_v2\\lpd_image (360).xml',
#  './lpd_dataset_v2\\lpd_image (361).xml',
#  './lpd_dataset_v2\\lpd_image (362).xml',
#  './lpd_dataset_v2\\lpd_image (363).xml',
#  './lpd_dataset_v2\\lpd_image (364).xml',
#  './lpd_dataset_v2\\lpd_image (365).xml',
#  './lpd_dataset_v2\\lpd_image (366).xml',
#  './lpd_dataset_v2\\lpd_image (367).xml',
#  './lpd_dataset_v2\\lpd_image (368).xml',
#  './lpd_dataset_v2\\lpd_image (369).xml',
#  './lpd_dataset_v2\\lpd_image (37).xml',
#  './lpd_dataset_v2\\lpd_image (370).xml',
#  './lpd_dataset_v2\\lpd_image (371).xml',
#  './lpd_dataset_v2\\lpd_image (372).xml',
#  './lpd_dataset_v2\\lpd_image (373).xml',
#  './lpd_dataset_v2\\lpd_image (374).xml',
#  './lpd_dataset_v2\\lpd_image (375).xml',
#  './lpd_dataset_v2\\lpd_image (376).xml',
#  './lpd_dataset_v2\\lpd_image (377).xml',
#  './lpd_dataset_v2\\lpd_image (378).xml',
#  './lpd_dataset_v2\\lpd_image (379).xml',
#  './lpd_dataset_v2\\lpd_image (38).xml',
#  './lpd_dataset_v2\\lpd_image (380).xml',
#  './lpd_dataset_v2\\lpd_image (381).xml',
#  './lpd_dataset_v2\\lpd_image (382).xml',
#  './lpd_dataset_v2\\lpd_image (383).xml',
#  './lpd_dataset_v2\\lpd_image (384).xml',
#  './lpd_dataset_v2\\lpd_image (385).xml',
#  './lpd_dataset_v2\\lpd_image (386).xml',
#  './lpd_dataset_v2\\lpd_image (387).xml',
#  './lpd_dataset_v2\\lpd_image (388).xml',
#  './lpd_dataset_v2\\lpd_image (389).xml',
#  './lpd_dataset_v2\\lpd_image (39).xml',
#  './lpd_dataset_v2\\lpd_image (390).xml',
#  './lpd_dataset_v2\\lpd_image (391).xml',
#  './lpd_dataset_v2\\lpd_image (392).xml',
#  './lpd_dataset_v2\\lpd_image (393).xml',
#  './lpd_dataset_v2\\lpd_image (394).xml',
#  './lpd_dataset_v2\\lpd_image (395).xml',
#  './lpd_dataset_v2\\lpd_image (396).xml',
#  './lpd_dataset_v2\\lpd_image (397).xml',
#  './lpd_dataset_v2\\lpd_image (398).xml',
#  './lpd_dataset_v2\\lpd_image (399).xml',
#  './lpd_dataset_v2\\lpd_image (4).xml',
#  './lpd_dataset_v2\\lpd_image (40).xml',
#  './lpd_dataset_v2\\lpd_image (400).xml',
#  './lpd_dataset_v2\\lpd_image (401).xml',
#  './lpd_dataset_v2\\lpd_image (402).xml',
#  './lpd_dataset_v2\\lpd_image (403).xml',
#  './lpd_dataset_v2\\lpd_image (404).xml',
#  './lpd_dataset_v2\\lpd_image (405).xml',
#  './lpd_dataset_v2\\lpd_image (406).xml',
#  './lpd_dataset_v2\\lpd_image (407).xml',
#  './lpd_dataset_v2\\lpd_image (408).xml',
#  './lpd_dataset_v2\\lpd_image (409).xml',
#  './lpd_dataset_v2\\lpd_image (41).xml',
#  './lpd_dataset_v2\\lpd_image (410).xml',
#  './lpd_dataset_v2\\lpd_image (411).xml',
#  './lpd_dataset_v2\\lpd_image (412).xml',
#  './lpd_dataset_v2\\lpd_image (413).xml',
#  './lpd_dataset_v2\\lpd_image (414).xml',
#  './lpd_dataset_v2\\lpd_image (415).xml',
#  './lpd_dataset_v2\\lpd_image (416).xml',
#  './lpd_dataset_v2\\lpd_image (417).xml',
#  './lpd_dataset_v2\\lpd_image (418).xml',
#  './lpd_dataset_v2\\lpd_image (419).xml',
#  './lpd_dataset_v2\\lpd_image (42).xml',
#  './lpd_dataset_v2\\lpd_image (420).xml',
#  './lpd_dataset_v2\\lpd_image (421).xml',
#  './lpd_dataset_v2\\lpd_image (422).xml',
#  './lpd_dataset_v2\\lpd_image (423).xml',
#  './lpd_dataset_v2\\lpd_image (424).xml',
#  './lpd_dataset_v2\\lpd_image (425).xml',
#  './lpd_dataset_v2\\lpd_image (426).xml',
#  './lpd_dataset_v2\\lpd_image (427).xml',
#  './lpd_dataset_v2\\lpd_image (428).xml',
#  './lpd_dataset_v2\\lpd_image (429).xml',
#  './lpd_dataset_v2\\lpd_image (43).xml',
#  './lpd_dataset_v2\\lpd_image (430).xml',
#  './lpd_dataset_v2\\lpd_image (431).xml',
#  './lpd_dataset_v2\\lpd_image (432).xml',
#  './lpd_dataset_v2\\lpd_image (433).xml',
#  './lpd_dataset_v2\\lpd_image (434).xml',
#  './lpd_dataset_v2\\lpd_image (435).xml',
#  './lpd_dataset_v2\\lpd_image (436).xml',
#  './lpd_dataset_v2\\lpd_image (437).xml',
#  './lpd_dataset_v2\\lpd_image (438).xml',
#  './lpd_dataset_v2\\lpd_image (439).xml',
#  './lpd_dataset_v2\\lpd_image (44).xml',
#  './lpd_dataset_v2\\lpd_image (440).xml',
#  './lpd_dataset_v2\\lpd_image (441).xml',
#  './lpd_dataset_v2\\lpd_image (442).xml',
#  './lpd_dataset_v2\\lpd_image (443).xml',
#  './lpd_dataset_v2\\lpd_image (444).xml',
#  './lpd_dataset_v2\\lpd_image (445).xml',
#  './lpd_dataset_v2\\lpd_image (446).xml',
#  './lpd_dataset_v2\\lpd_image (447).xml',
#  './lpd_dataset_v2\\lpd_image (448).xml',
#  './lpd_dataset_v2\\lpd_image (449).xml',
#  './lpd_dataset_v2\\lpd_image (45).xml',
#  './lpd_dataset_v2\\lpd_image (450).xml',
#  './lpd_dataset_v2\\lpd_image (451).xml',
#  './lpd_dataset_v2\\lpd_image (452).xml',
#  './lpd_dataset_v2\\lpd_image (453).xml',
#  './lpd_dataset_v2\\lpd_image (454).xml',
#  './lpd_dataset_v2\\lpd_image (455).xml',
#  './lpd_dataset_v2\\lpd_image (456).xml',
#  './lpd_dataset_v2\\lpd_image (457).xml',
#  './lpd_dataset_v2\\lpd_image (458).xml',
#  './lpd_dataset_v2\\lpd_image (459).xml',
#  './lpd_dataset_v2\\lpd_image (46).xml',
#  './lpd_dataset_v2\\lpd_image (460).xml',
#  './lpd_dataset_v2\\lpd_image (461).xml',
#  './lpd_dataset_v2\\lpd_image (462).xml',
#  './lpd_dataset_v2\\lpd_image (463).xml',
#  './lpd_dataset_v2\\lpd_image (464).xml',
#  './lpd_dataset_v2\\lpd_image (465).xml',
#  './lpd_dataset_v2\\lpd_image (466).xml',
#  './lpd_dataset_v2\\lpd_image (467).xml',
#  './lpd_dataset_v2\\lpd_image (468).xml',
#  './lpd_dataset_v2\\lpd_image (469).xml',
#  './lpd_dataset_v2\\lpd_image (47).xml',
#  './lpd_dataset_v2\\lpd_image (470).xml',
#  './lpd_dataset_v2\\lpd_image (471).xml',
#  './lpd_dataset_v2\\lpd_image (472).xml',
#  './lpd_dataset_v2\\lpd_image (473).xml',
#  './lpd_dataset_v2\\lpd_image (474).xml',
#  './lpd_dataset_v2\\lpd_image (475).xml',
#  './lpd_dataset_v2\\lpd_image (476).xml',
#  './lpd_dataset_v2\\lpd_image (477).xml',
#  './lpd_dataset_v2\\lpd_image (478).xml',
#  './lpd_dataset_v2\\lpd_image (479).xml',
#  './lpd_dataset_v2\\lpd_image (48).xml',
#  './lpd_dataset_v2\\lpd_image (480).xml',
#  './lpd_dataset_v2\\lpd_image (481).xml',
#  './lpd_dataset_v2\\lpd_image (482).xml',
#  './lpd_dataset_v2\\lpd_image (483).xml',
#  './lpd_dataset_v2\\lpd_image (484).xml',
#  './lpd_dataset_v2\\lpd_image (485).xml',
#  './lpd_dataset_v2\\lpd_image (486).xml',
#  './lpd_dataset_v2\\lpd_image (487).xml',
#  './lpd_dataset_v2\\lpd_image (488).xml',
#  './lpd_dataset_v2\\lpd_image (489).xml',
#  './lpd_dataset_v2\\lpd_image (49).xml',
#  './lpd_dataset_v2\\lpd_image (490).xml',
#  './lpd_dataset_v2\\lpd_image (491).xml',
#  './lpd_dataset_v2\\lpd_image (492).xml',
#  './lpd_dataset_v2\\lpd_image (493).xml',
#  './lpd_dataset_v2\\lpd_image (494).xml',
#  './lpd_dataset_v2\\lpd_image (495).xml',
#  './lpd_dataset_v2\\lpd_image (496).xml',
#  './lpd_dataset_v2\\lpd_image (497).xml',
#  './lpd_dataset_v2\\lpd_image (498).xml',
#  './lpd_dataset_v2\\lpd_image (499).xml',
#  './lpd_dataset_v2\\lpd_image (5).xml',
#  './lpd_dataset_v2\\lpd_image (50).xml',
#  './lpd_dataset_v2\\lpd_image (500).xml',
#  './lpd_dataset_v2\\lpd_image (501).xml',
#  './lpd_dataset_v2\\lpd_image (502).xml',
#  './lpd_dataset_v2\\lpd_image (503).xml',
#  './lpd_dataset_v2\\lpd_image (504).xml',
#  './lpd_dataset_v2\\lpd_image (505).xml',
#  './lpd_dataset_v2\\lpd_image (506).xml',
#  './lpd_dataset_v2\\lpd_image (507).xml',
#  './lpd_dataset_v2\\lpd_image (508).xml',
#  './lpd_dataset_v2\\lpd_image (509).xml',
#  './lpd_dataset_v2\\lpd_image (51).xml',
#  './lpd_dataset_v2\\lpd_image (510).xml',
#  './lpd_dataset_v2\\lpd_image (511).xml',
#  './lpd_dataset_v2\\lpd_image (512).xml',
#  './lpd_dataset_v2\\lpd_image (513).xml',
#  './lpd_dataset_v2\\lpd_image (514).xml',
#  './lpd_dataset_v2\\lpd_image (515).xml',
#  './lpd_dataset_v2\\lpd_image (516).xml',
#  './lpd_dataset_v2\\lpd_image (517).xml',
#  './lpd_dataset_v2\\lpd_image (518).xml',
#  './lpd_dataset_v2\\lpd_image (519).xml',
#  './lpd_dataset_v2\\lpd_image (52).xml',
#  './lpd_dataset_v2\\lpd_image (520).xml',
#  './lpd_dataset_v2\\lpd_image (521).xml',
#  './lpd_dataset_v2\\lpd_image (522).xml',
#  './lpd_dataset_v2\\lpd_image (523).xml',
#  './lpd_dataset_v2\\lpd_image (524).xml',
#  './lpd_dataset_v2\\lpd_image (525).xml',
#  './lpd_dataset_v2\\lpd_image (526).xml',
#  './lpd_dataset_v2\\lpd_image (527).xml',
#  './lpd_dataset_v2\\lpd_image (528).xml',
#  './lpd_dataset_v2\\lpd_image (529).xml',
#  './lpd_dataset_v2\\lpd_image (53).xml',
#  './lpd_dataset_v2\\lpd_image (530).xml',
#  './lpd_dataset_v2\\lpd_image (531).xml',
#  './lpd_dataset_v2\\lpd_image (532).xml',
#  './lpd_dataset_v2\\lpd_image (533).xml',
#  './lpd_dataset_v2\\lpd_image (534).xml',
#  './lpd_dataset_v2\\lpd_image (535).xml',
#  './lpd_dataset_v2\\lpd_image (536).xml',
#  './lpd_dataset_v2\\lpd_image (537).xml',
#  './lpd_dataset_v2\\lpd_image (538).xml',
#  './lpd_dataset_v2\\lpd_image (539).xml',
#  './lpd_dataset_v2\\lpd_image (54).xml',
#  './lpd_dataset_v2\\lpd_image (540).xml',
#  './lpd_dataset_v2\\lpd_image (541).xml',
#  './lpd_dataset_v2\\lpd_image (542).xml',
#  './lpd_dataset_v2\\lpd_image (543).xml',
#  './lpd_dataset_v2\\lpd_image (544).xml',
#  './lpd_dataset_v2\\lpd_image (545).xml',
#  './lpd_dataset_v2\\lpd_image (546).xml',
#  './lpd_dataset_v2\\lpd_image (547).xml',
#  './lpd_dataset_v2\\lpd_image (548).xml',
#  './lpd_dataset_v2\\lpd_image (549).xml',
#  './lpd_dataset_v2\\lpd_image (55).xml',
#  './lpd_dataset_v2\\lpd_image (550).xml',
#  './lpd_dataset_v2\\lpd_image (551).xml',
#  './lpd_dataset_v2\\lpd_image (552).xml',
#  './lpd_dataset_v2\\lpd_image (553).xml',
#  './lpd_dataset_v2\\lpd_image (554).xml',
#  './lpd_dataset_v2\\lpd_image (555).xml',
#  './lpd_dataset_v2\\lpd_image (556).xml',
#  './lpd_dataset_v2\\lpd_image (557).xml',
#  './lpd_dataset_v2\\lpd_image (558).xml',
#  './lpd_dataset_v2\\lpd_image (559).xml',
#  './lpd_dataset_v2\\lpd_image (56).xml',
#  './lpd_dataset_v2\\lpd_image (560).xml',
#  './lpd_dataset_v2\\lpd_image (561).xml',
#  './lpd_dataset_v2\\lpd_image (562).xml',
#  './lpd_dataset_v2\\lpd_image (563).xml',
#  './lpd_dataset_v2\\lpd_image (564).xml',
#  './lpd_dataset_v2\\lpd_image (565).xml',
#  './lpd_dataset_v2\\lpd_image (566).xml',
#  './lpd_dataset_v2\\lpd_image (567).xml',
#  './lpd_dataset_v2\\lpd_image (568).xml',
#  './lpd_dataset_v2\\lpd_image (569).xml',
#  './lpd_dataset_v2\\lpd_image (57).xml',
#  './lpd_dataset_v2\\lpd_image (570).xml',
#  './lpd_dataset_v2\\lpd_image (571).xml',
#  './lpd_dataset_v2\\lpd_image (572).xml',
#  './lpd_dataset_v2\\lpd_image (573).xml',
#  './lpd_dataset_v2\\lpd_image (574).xml',
#  './lpd_dataset_v2\\lpd_image (575).xml',
#  './lpd_dataset_v2\\lpd_image (576).xml',
#  './lpd_dataset_v2\\lpd_image (577).xml',
#  './lpd_dataset_v2\\lpd_image (578).xml',
#  './lpd_dataset_v2\\lpd_image (579).xml',
#  './lpd_dataset_v2\\lpd_image (58).xml',
#  './lpd_dataset_v2\\lpd_image (580).xml',
#  './lpd_dataset_v2\\lpd_image (581).xml',
#  './lpd_dataset_v2\\lpd_image (582).xml',
#  './lpd_dataset_v2\\lpd_image (583).xml',
#  './lpd_dataset_v2\\lpd_image (584).xml',
#  './lpd_dataset_v2\\lpd_image (585).xml',
#  './lpd_dataset_v2\\lpd_image (586).xml',
#  './lpd_dataset_v2\\lpd_image (587).xml',
#  './lpd_dataset_v2\\lpd_image (588).xml',
#  './lpd_dataset_v2\\lpd_image (589).xml',
#  './lpd_dataset_v2\\lpd_image (59).xml',
#  './lpd_dataset_v2\\lpd_image (590).xml',
#  './lpd_dataset_v2\\lpd_image (591).xml',
#  './lpd_dataset_v2\\lpd_image (592).xml',
#  './lpd_dataset_v2\\lpd_image (593).xml',
#  './lpd_dataset_v2\\lpd_image (594).xml',
#  './lpd_dataset_v2\\lpd_image (595).xml',
#  './lpd_dataset_v2\\lpd_image (596).xml',
#  './lpd_dataset_v2\\lpd_image (597).xml',
#  './lpd_dataset_v2\\lpd_image (598).xml',
#  './lpd_dataset_v2\\lpd_image (599).xml',
#  './lpd_dataset_v2\\lpd_image (6).xml',
#  './lpd_dataset_v2\\lpd_image (60).xml',
#  './lpd_dataset_v2\\lpd_image (600).xml',
#  './lpd_dataset_v2\\lpd_image (601).xml',
#  './lpd_dataset_v2\\lpd_image (602).xml',
#  './lpd_dataset_v2\\lpd_image (603).xml',
#  './lpd_dataset_v2\\lpd_image (604).xml',
#  './lpd_dataset_v2\\lpd_image (605).xml',
#  './lpd_dataset_v2\\lpd_image (606).xml',
#  './lpd_dataset_v2\\lpd_image (607).xml',
#  './lpd_dataset_v2\\lpd_image (608).xml',
#  './lpd_dataset_v2\\lpd_image (609).xml',
#  './lpd_dataset_v2\\lpd_image (61).xml',
#  './lpd_dataset_v2\\lpd_image (610).xml',
#  './lpd_dataset_v2\\lpd_image (611).xml',
#  './lpd_dataset_v2\\lpd_image (612).xml',
#  './lpd_dataset_v2\\lpd_image (613).xml',
#  './lpd_dataset_v2\\lpd_image (614).xml',
#  './lpd_dataset_v2\\lpd_image (615).xml',
#  './lpd_dataset_v2\\lpd_image (616).xml',
#  './lpd_dataset_v2\\lpd_image (617).xml',
#  './lpd_dataset_v2\\lpd_image (618).xml',
#  './lpd_dataset_v2\\lpd_image (619).xml',
#  './lpd_dataset_v2\\lpd_image (62).xml',
#  './lpd_dataset_v2\\lpd_image (620).xml',
#  './lpd_dataset_v2\\lpd_image (621).xml',
#  './lpd_dataset_v2\\lpd_image (622).xml',
#  './lpd_dataset_v2\\lpd_image (623).xml',
#  './lpd_dataset_v2\\lpd_image (624).xml',
#  './lpd_dataset_v2\\lpd_image (625).xml',
#  './lpd_dataset_v2\\lpd_image (626).xml',
#  './lpd_dataset_v2\\lpd_image (627).xml',
#  './lpd_dataset_v2\\lpd_image (628).xml',
#  './lpd_dataset_v2\\lpd_image (629).xml',
#  './lpd_dataset_v2\\lpd_image (63).xml',
#  './lpd_dataset_v2\\lpd_image (630).xml',
#  './lpd_dataset_v2\\lpd_image (631).xml',
#  './lpd_dataset_v2\\lpd_image (632).xml',
#  './lpd_dataset_v2\\lpd_image (633).xml',
#  './lpd_dataset_v2\\lpd_image (634).xml',
#  './lpd_dataset_v2\\lpd_image (635).xml',
#  './lpd_dataset_v2\\lpd_image (636).xml',
#  './lpd_dataset_v2\\lpd_image (637).xml',
#  './lpd_dataset_v2\\lpd_image (638).xml',
#  './lpd_dataset_v2\\lpd_image (639).xml',
#  './lpd_dataset_v2\\lpd_image (64).xml',
#  './lpd_dataset_v2\\lpd_image (640).xml',
#  './lpd_dataset_v2\\lpd_image (641).xml',
#  './lpd_dataset_v2\\lpd_image (642).xml',
#  './lpd_dataset_v2\\lpd_image (643).xml',
#  './lpd_dataset_v2\\lpd_image (644).xml',
#  './lpd_dataset_v2\\lpd_image (645).xml',
#  './lpd_dataset_v2\\lpd_image (646).xml',
#  './lpd_dataset_v2\\lpd_image (647).xml',
#  './lpd_dataset_v2\\lpd_image (648).xml',
#  './lpd_dataset_v2\\lpd_image (649).xml',
#  './lpd_dataset_v2\\lpd_image (65).xml',
#  './lpd_dataset_v2\\lpd_image (650).xml',
#  './lpd_dataset_v2\\lpd_image (651).xml',
#  './lpd_dataset_v2\\lpd_image (652).xml',
#  './lpd_dataset_v2\\lpd_image (653).xml',
#  './lpd_dataset_v2\\lpd_image (654).xml',
#  './lpd_dataset_v2\\lpd_image (655).xml',
#  './lpd_dataset_v2\\lpd_image (656).xml',
#  './lpd_dataset_v2\\lpd_image (657).xml',
#  './lpd_dataset_v2\\lpd_image (658).xml',
#  './lpd_dataset_v2\\lpd_image (659).xml',
#  './lpd_dataset_v2\\lpd_image (66).xml',
#  './lpd_dataset_v2\\lpd_image (660).xml',
#  './lpd_dataset_v2\\lpd_image (661).xml',
#  './lpd_dataset_v2\\lpd_image (662).xml',
#  './lpd_dataset_v2\\lpd_image (663).xml',
#  './lpd_dataset_v2\\lpd_image (664).xml',
#  './lpd_dataset_v2\\lpd_image (665).xml',
#  './lpd_dataset_v2\\lpd_image (666).xml',
#  './lpd_dataset_v2\\lpd_image (667).xml',
#  './lpd_dataset_v2\\lpd_image (668).xml',
#  './lpd_dataset_v2\\lpd_image (669).xml',
#  './lpd_dataset_v2\\lpd_image (67).xml',
#  './lpd_dataset_v2\\lpd_image (670).xml',
#  './lpd_dataset_v2\\lpd_image (671).xml',
#  './lpd_dataset_v2\\lpd_image (672).xml',
#  './lpd_dataset_v2\\lpd_image (673).xml',
#  './lpd_dataset_v2\\lpd_image (674).xml',
#  './lpd_dataset_v2\\lpd_image (675).xml',
#  './lpd_dataset_v2\\lpd_image (676).xml',
#  './lpd_dataset_v2\\lpd_image (677).xml',
#  './lpd_dataset_v2\\lpd_image (678).xml',
#  './lpd_dataset_v2\\lpd_image (679).xml',
#  './lpd_dataset_v2\\lpd_image (68).xml',
#  './lpd_dataset_v2\\lpd_image (680).xml',
#  './lpd_dataset_v2\\lpd_image (681).xml',
#  './lpd_dataset_v2\\lpd_image (682).xml',
#  './lpd_dataset_v2\\lpd_image (683).xml',
#  './lpd_dataset_v2\\lpd_image (684).xml',
#  './lpd_dataset_v2\\lpd_image (685).xml',
#  './lpd_dataset_v2\\lpd_image (686).xml',
#  './lpd_dataset_v2\\lpd_image (687).xml',
#  './lpd_dataset_v2\\lpd_image (688).xml',
#  './lpd_dataset_v2\\lpd_image (689).xml',
#  './lpd_dataset_v2\\lpd_image (69).xml',
#  './lpd_dataset_v2\\lpd_image (690).xml',
#  './lpd_dataset_v2\\lpd_image (691).xml',
#  './lpd_dataset_v2\\lpd_image (692).xml',
#  './lpd_dataset_v2\\lpd_image (693).xml',
#  './lpd_dataset_v2\\lpd_image (694).xml',
#  './lpd_dataset_v2\\lpd_image (695).xml',
#  './lpd_dataset_v2\\lpd_image (696).xml',
#  './lpd_dataset_v2\\lpd_image (697).xml',
#  './lpd_dataset_v2\\lpd_image (698).xml',
#  './lpd_dataset_v2\\lpd_image (699).xml',
#  './lpd_dataset_v2\\lpd_image (7).xml',
#  './lpd_dataset_v2\\lpd_image (70).xml',
#  './lpd_dataset_v2\\lpd_image (700).xml',
#  './lpd_dataset_v2\\lpd_image (701).xml',
#  './lpd_dataset_v2\\lpd_image (702).xml',
#  './lpd_dataset_v2\\lpd_image (703).xml',
#  './lpd_dataset_v2\\lpd_image (704).xml',
#  './lpd_dataset_v2\\lpd_image (705).xml',
#  './lpd_dataset_v2\\lpd_image (706).xml',
#  './lpd_dataset_v2\\lpd_image (707).xml',
#  './lpd_dataset_v2\\lpd_image (708).xml',
#  './lpd_dataset_v2\\lpd_image (709).xml',
#  './lpd_dataset_v2\\lpd_image (71).xml',
#  './lpd_dataset_v2\\lpd_image (710).xml',
#  './lpd_dataset_v2\\lpd_image (711).xml',
#  './lpd_dataset_v2\\lpd_image (712).xml',
#  './lpd_dataset_v2\\lpd_image (713).xml',
#  './lpd_dataset_v2\\lpd_image (714).xml',
#  './lpd_dataset_v2\\lpd_image (715).xml',
#  './lpd_dataset_v2\\lpd_image (716).xml',
#  './lpd_dataset_v2\\lpd_image (717).xml',
#  './lpd_dataset_v2\\lpd_image (718).xml',
#  './lpd_dataset_v2\\lpd_image (719).xml',
#  './lpd_dataset_v2\\lpd_image (72).xml',
#  './lpd_dataset_v2\\lpd_image (720).xml',
#  './lpd_dataset_v2\\lpd_image (721).xml',
#  './lpd_dataset_v2\\lpd_image (722).xml',
#  './lpd_dataset_v2\\lpd_image (723).xml',
#  './lpd_dataset_v2\\lpd_image (724).xml',
#  './lpd_dataset_v2\\lpd_image (725).xml',
#  './lpd_dataset_v2\\lpd_image (726).xml',
#  './lpd_dataset_v2\\lpd_image (727).xml',
#  './lpd_dataset_v2\\lpd_image (728).xml',
#  './lpd_dataset_v2\\lpd_image (729).xml',
#  './lpd_dataset_v2\\lpd_image (73).xml',
#  './lpd_dataset_v2\\lpd_image (730).xml',
#  './lpd_dataset_v2\\lpd_image (731).xml',
#  './lpd_dataset_v2\\lpd_image (732).xml',
#  './lpd_dataset_v2\\lpd_image (733).xml',
#  './lpd_dataset_v2\\lpd_image (734).xml',
#  './lpd_dataset_v2\\lpd_image (735).xml',
#  './lpd_dataset_v2\\lpd_image (736).xml',
#  './lpd_dataset_v2\\lpd_image (737).xml',
#  './lpd_dataset_v2\\lpd_image (738).xml',
#  './lpd_dataset_v2\\lpd_image (739).xml',
#  './lpd_dataset_v2\\lpd_image (74).xml',
#  './lpd_dataset_v2\\lpd_image (740).xml',
#  './lpd_dataset_v2\\lpd_image (741).xml',
#  './lpd_dataset_v2\\lpd_image (742).xml',
#  './lpd_dataset_v2\\lpd_image (743).xml',
#  './lpd_dataset_v2\\lpd_image (744).xml',
#  './lpd_dataset_v2\\lpd_image (745).xml',
#  './lpd_dataset_v2\\lpd_image (746).xml',
#  './lpd_dataset_v2\\lpd_image (747).xml',
#  './lpd_dataset_v2\\lpd_image (748).xml',
#  './lpd_dataset_v2\\lpd_image (749).xml',
#  './lpd_dataset_v2\\lpd_image (75).xml',
#  './lpd_dataset_v2\\lpd_image (750).xml',
#  './lpd_dataset_v2\\lpd_image (751).xml',
#  './lpd_dataset_v2\\lpd_image (752).xml',
#  './lpd_dataset_v2\\lpd_image (753).xml',
#  './lpd_dataset_v2\\lpd_image (754).xml',
#  './lpd_dataset_v2\\lpd_image (755).xml',
#  './lpd_dataset_v2\\lpd_image (756).xml',
#  './lpd_dataset_v2\\lpd_image (757).xml',
#  './lpd_dataset_v2\\lpd_image (758).xml',
#  './lpd_dataset_v2\\lpd_image (759).xml',
#  './lpd_dataset_v2\\lpd_image (76).xml',
#  './lpd_dataset_v2\\lpd_image (760).xml',
#  './lpd_dataset_v2\\lpd_image (761).xml',
#  './lpd_dataset_v2\\lpd_image (762).xml',
#  './lpd_dataset_v2\\lpd_image (763).xml',
#  './lpd_dataset_v2\\lpd_image (764).xml',
#  './lpd_dataset_v2\\lpd_image (765).xml',
#  './lpd_dataset_v2\\lpd_image (766).xml',
#  './lpd_dataset_v2\\lpd_image (767).xml',
#  './lpd_dataset_v2\\lpd_image (768).xml',
#  './lpd_dataset_v2\\lpd_image (769).xml',
#  './lpd_dataset_v2\\lpd_image (77).xml',
#  './lpd_dataset_v2\\lpd_image (770).xml',
#  './lpd_dataset_v2\\lpd_image (771).xml',
#  './lpd_dataset_v2\\lpd_image (772).xml',
#  './lpd_dataset_v2\\lpd_image (773).xml',
#  './lpd_dataset_v2\\lpd_image (774).xml',
#  './lpd_dataset_v2\\lpd_image (775).xml',
#  './lpd_dataset_v2\\lpd_image (776).xml',
#  './lpd_dataset_v2\\lpd_image (777).xml',
#  './lpd_dataset_v2\\lpd_image (778).xml',
#  './lpd_dataset_v2\\lpd_image (779).xml',
#  './lpd_dataset_v2\\lpd_image (78).xml',
#  './lpd_dataset_v2\\lpd_image (780).xml',
#  './lpd_dataset_v2\\lpd_image (781).xml',
#  './lpd_dataset_v2\\lpd_image (782).xml',
#  './lpd_dataset_v2\\lpd_image (783).xml',
#  './lpd_dataset_v2\\lpd_image (784).xml',
#  './lpd_dataset_v2\\lpd_image (785).xml',
#  './lpd_dataset_v2\\lpd_image (786).xml',
#  './lpd_dataset_v2\\lpd_image (787).xml',
#  './lpd_dataset_v2\\lpd_image (788).xml',
#  './lpd_dataset_v2\\lpd_image (789).xml',
#  './lpd_dataset_v2\\lpd_image (79).xml',
#  './lpd_dataset_v2\\lpd_image (790).xml',
#  './lpd_dataset_v2\\lpd_image (791).xml',
#  './lpd_dataset_v2\\lpd_image (792).xml',
#  './lpd_dataset_v2\\lpd_image (793).xml',
#  './lpd_dataset_v2\\lpd_image (794).xml',
#  './lpd_dataset_v2\\lpd_image (795).xml',
#  './lpd_dataset_v2\\lpd_image (796).xml',
#  './lpd_dataset_v2\\lpd_image (797).xml',
#  './lpd_dataset_v2\\lpd_image (798).xml',
#  './lpd_dataset_v2\\lpd_image (799).xml',
#  './lpd_dataset_v2\\lpd_image (8).xml',
#  './lpd_dataset_v2\\lpd_image (80).xml',
#  './lpd_dataset_v2\\lpd_image (800).xml',
#  './lpd_dataset_v2\\lpd_image (801).xml',
#  './lpd_dataset_v2\\lpd_image (802).xml',
#  './lpd_dataset_v2\\lpd_image (803).xml',
#  './lpd_dataset_v2\\lpd_image (804).xml',
#  './lpd_dataset_v2\\lpd_image (805).xml',
#  './lpd_dataset_v2\\lpd_image (806).xml',
#  './lpd_dataset_v2\\lpd_image (807).xml',
#  './lpd_dataset_v2\\lpd_image (808).xml',
#  './lpd_dataset_v2\\lpd_image (809).xml',
#  './lpd_dataset_v2\\lpd_image (81).xml',
#  './lpd_dataset_v2\\lpd_image (810).xml',
#  './lpd_dataset_v2\\lpd_image (811).xml',
#  './lpd_dataset_v2\\lpd_image (812).xml',
#  './lpd_dataset_v2\\lpd_image (813).xml',
#  './lpd_dataset_v2\\lpd_image (814).xml',
#  './lpd_dataset_v2\\lpd_image (815).xml',
#  './lpd_dataset_v2\\lpd_image (816).xml',
#  './lpd_dataset_v2\\lpd_image (817).xml',
#  './lpd_dataset_v2\\lpd_image (818).xml',
#  './lpd_dataset_v2\\lpd_image (819).xml',
#  './lpd_dataset_v2\\lpd_image (82).xml',
#  './lpd_dataset_v2\\lpd_image (820).xml',
#  './lpd_dataset_v2\\lpd_image (821).xml',
#  './lpd_dataset_v2\\lpd_image (822).xml',
#  './lpd_dataset_v2\\lpd_image (823).xml',
#  './lpd_dataset_v2\\lpd_image (824).xml',
#  './lpd_dataset_v2\\lpd_image (825).xml',
#  './lpd_dataset_v2\\lpd_image (826).xml',
#  './lpd_dataset_v2\\lpd_image (827).xml',
#  './lpd_dataset_v2\\lpd_image (828).xml',
#  './lpd_dataset_v2\\lpd_image (829).xml',
#  './lpd_dataset_v2\\lpd_image (83).xml',
#  './lpd_dataset_v2\\lpd_image (830).xml',
#  './lpd_dataset_v2\\lpd_image (831).xml',
#  './lpd_dataset_v2\\lpd_image (832).xml',
#  './lpd_dataset_v2\\lpd_image (833).xml',
#  './lpd_dataset_v2\\lpd_image (834).xml',
#  './lpd_dataset_v2\\lpd_image (835).xml',
#  './lpd_dataset_v2\\lpd_image (836).xml',
#  './lpd_dataset_v2\\lpd_image (837).xml',
#  './lpd_dataset_v2\\lpd_image (838).xml',
#  './lpd_dataset_v2\\lpd_image (839).xml',
#  './lpd_dataset_v2\\lpd_image (84).xml',
#  './lpd_dataset_v2\\lpd_image (840).xml',
#  './lpd_dataset_v2\\lpd_image (841).xml',
#  './lpd_dataset_v2\\lpd_image (842).xml',
#  './lpd_dataset_v2\\lpd_image (843).xml',
#  './lpd_dataset_v2\\lpd_image (844).xml',
#  './lpd_dataset_v2\\lpd_image (845).xml',
#  './lpd_dataset_v2\\lpd_image (846).xml',
#  './lpd_dataset_v2\\lpd_image (847).xml',
#  './lpd_dataset_v2\\lpd_image (848).xml',
#  './lpd_dataset_v2\\lpd_image (849).xml',
#  './lpd_dataset_v2\\lpd_image (85).xml',
#  './lpd_dataset_v2\\lpd_image (850).xml',
#  './lpd_dataset_v2\\lpd_image (851).xml',
#  './lpd_dataset_v2\\lpd_image (852).xml',
#  './lpd_dataset_v2\\lpd_image (853).xml',
#  './lpd_dataset_v2\\lpd_image (854).xml',
#  './lpd_dataset_v2\\lpd_image (855).xml',
#  './lpd_dataset_v2\\lpd_image (856).xml',
#  './lpd_dataset_v2\\lpd_image (857).xml',
#  './lpd_dataset_v2\\lpd_image (858).xml',
#  './lpd_dataset_v2\\lpd_image (859).xml',
#  './lpd_dataset_v2\\lpd_image (86).xml',
#  './lpd_dataset_v2\\lpd_image (860).xml',
#  './lpd_dataset_v2\\lpd_image (861).xml',
#  './lpd_dataset_v2\\lpd_image (862).xml',
#  './lpd_dataset_v2\\lpd_image (863).xml',
#  './lpd_dataset_v2\\lpd_image (864).xml',
#  './lpd_dataset_v2\\lpd_image (865).xml',
#  './lpd_dataset_v2\\lpd_image (866).xml',
#  './lpd_dataset_v2\\lpd_image (867).xml',
#  './lpd_dataset_v2\\lpd_image (868).xml',
#  './lpd_dataset_v2\\lpd_image (869).xml',
#  './lpd_dataset_v2\\lpd_image (87).xml',
#  './lpd_dataset_v2\\lpd_image (870).xml',
#  './lpd_dataset_v2\\lpd_image (871).xml',
#  './lpd_dataset_v2\\lpd_image (872).xml',
#  './lpd_dataset_v2\\lpd_image (873).xml',
#  './lpd_dataset_v2\\lpd_image (874).xml',
#  './lpd_dataset_v2\\lpd_image (875).xml',
#  './lpd_dataset_v2\\lpd_image (876).xml',
#  './lpd_dataset_v2\\lpd_image (877).xml',
#  './lpd_dataset_v2\\lpd_image (878).xml',
#  './lpd_dataset_v2\\lpd_image (879).xml',
#  './lpd_dataset_v2\\lpd_image (88).xml',
#  './lpd_dataset_v2\\lpd_image (880).xml',
#  './lpd_dataset_v2\\lpd_image (881).xml',
#  './lpd_dataset_v2\\lpd_image (882).xml',
#  './lpd_dataset_v2\\lpd_image (883).xml',
#  './lpd_dataset_v2\\lpd_image (884).xml',
#  './lpd_dataset_v2\\lpd_image (885).xml',
#  './lpd_dataset_v2\\lpd_image (886).xml',
#  './lpd_dataset_v2\\lpd_image (887).xml',
#  './lpd_dataset_v2\\lpd_image (888).xml',
#  './lpd_dataset_v2\\lpd_image (889).xml',
#  './lpd_dataset_v2\\lpd_image (89).xml',
#  './lpd_dataset_v2\\lpd_image (890).xml',
#  './lpd_dataset_v2\\lpd_image (891).xml',
#  './lpd_dataset_v2\\lpd_image (892).xml',
#  './lpd_dataset_v2\\lpd_image (893).xml',
#  './lpd_dataset_v2\\lpd_image (894).xml',
#  './lpd_dataset_v2\\lpd_image (895).xml',
#  './lpd_dataset_v2\\lpd_image (896).xml',
#  './lpd_dataset_v2\\lpd_image (897).xml',
#  './lpd_dataset_v2\\lpd_image (898).xml',
#  './lpd_dataset_v2\\lpd_image (899).xml',
#  './lpd_dataset_v2\\lpd_image (9).xml',
#  './lpd_dataset_v2\\lpd_image (90).xml',
#  './lpd_dataset_v2\\lpd_image (900).xml',
#  './lpd_dataset_v2\\lpd_image (901).xml',
#  './lpd_dataset_v2\\lpd_image (902).xml',
#  './lpd_dataset_v2\\lpd_image (903).xml',
#  './lpd_dataset_v2\\lpd_image (904).xml',
#  './lpd_dataset_v2\\lpd_image (905).xml',
#  './lpd_dataset_v2\\lpd_image (906).xml',
#  './lpd_dataset_v2\\lpd_image (907).xml',
#  './lpd_dataset_v2\\lpd_image (908).xml',
#  './lpd_dataset_v2\\lpd_image (909).xml',
#  './lpd_dataset_v2\\lpd_image (91).xml',
#  './lpd_dataset_v2\\lpd_image (910).xml',
#  './lpd_dataset_v2\\lpd_image (911).xml',
#  './lpd_dataset_v2\\lpd_image (912).xml',
#  './lpd_dataset_v2\\lpd_image (913).xml',
#  './lpd_dataset_v2\\lpd_image (914).xml',
#  './lpd_dataset_v2\\lpd_image (915).xml',
#  './lpd_dataset_v2\\lpd_image (916).xml',
#  './lpd_dataset_v2\\lpd_image (917).xml',
#  './lpd_dataset_v2\\lpd_image (918).xml',
#  './lpd_dataset_v2\\lpd_image (919).xml',
#  './lpd_dataset_v2\\lpd_image (92).xml',
#  './lpd_dataset_v2\\lpd_image (920).xml',
#  './lpd_dataset_v2\\lpd_image (921).xml',
#  './lpd_dataset_v2\\lpd_image (922).xml',
#  './lpd_dataset_v2\\lpd_image (923).xml',
#  './lpd_dataset_v2\\lpd_image (924).xml',
#  './lpd_dataset_v2\\lpd_image (925).xml',
#  './lpd_dataset_v2\\lpd_image (926).xml',
#  './lpd_dataset_v2\\lpd_image (927).xml',
#  './lpd_dataset_v2\\lpd_image (928).xml',
#  './lpd_dataset_v2\\lpd_image (929).xml',
#  './lpd_dataset_v2\\lpd_image (93).xml',
#  './lpd_dataset_v2\\lpd_image (930).xml',
#  './lpd_dataset_v2\\lpd_image (931).xml',
#  './lpd_dataset_v2\\lpd_image (932).xml',
#  './lpd_dataset_v2\\lpd_image (933).xml',
#  './lpd_dataset_v2\\lpd_image (934).xml',
#  './lpd_dataset_v2\\lpd_image (935).xml',
#  './lpd_dataset_v2\\lpd_image (936).xml',
#  './lpd_dataset_v2\\lpd_image (937).xml',
#  './lpd_dataset_v2\\lpd_image (938).xml',
#  './lpd_dataset_v2\\lpd_image (939).xml',
#  './lpd_dataset_v2\\lpd_image (94).xml',
#  './lpd_dataset_v2\\lpd_image (940).xml',
#  './lpd_dataset_v2\\lpd_image (941).xml',
#  './lpd_dataset_v2\\lpd_image (942).xml',
#  './lpd_dataset_v2\\lpd_image (943).xml',
#  './lpd_dataset_v2\\lpd_image (944).xml',
#  './lpd_dataset_v2\\lpd_image (945).xml',
#  './lpd_dataset_v2\\lpd_image (946).xml',
#  './lpd_dataset_v2\\lpd_image (947).xml',
#  './lpd_dataset_v2\\lpd_image (948).xml',
#  './lpd_dataset_v2\\lpd_image (949).xml',
#  './lpd_dataset_v2\\lpd_image (95).xml',
#  './lpd_dataset_v2\\lpd_image (950).xml',
#  './lpd_dataset_v2\\lpd_image (951).xml',
#  './lpd_dataset_v2\\lpd_image (952).xml',
#  './lpd_dataset_v2\\lpd_image (953).xml',
#  './lpd_dataset_v2\\lpd_image (954).xml',
#  './lpd_dataset_v2\\lpd_image (955).xml',
#  './lpd_dataset_v2\\lpd_image (956).xml',
#  './lpd_dataset_v2\\lpd_image (957).xml',
#  './lpd_dataset_v2\\lpd_image (958).xml',
#  './lpd_dataset_v2\\lpd_image (959).xml',
#  './lpd_dataset_v2\\lpd_image (96).xml',
#  './lpd_dataset_v2\\lpd_image (960).xml',
#  './lpd_dataset_v2\\lpd_image (961).xml',
#  './lpd_dataset_v2\\lpd_image (962).xml',
#  './lpd_dataset_v2\\lpd_image (963).xml',
#  './lpd_dataset_v2\\lpd_image (964).xml',
#  './lpd_dataset_v2\\lpd_image (965).xml',
#  './lpd_dataset_v2\\lpd_image (966).xml',
#  './lpd_dataset_v2\\lpd_image (967).xml',
#  './lpd_dataset_v2\\lpd_image (968).xml',
#  './lpd_dataset_v2\\lpd_image (969).xml',
#  './lpd_dataset_v2\\lpd_image (97).xml',
#  './lpd_dataset_v2\\lpd_image (970).xml',
#  './lpd_dataset_v2\\lpd_image (971).xml',
#  './lpd_dataset_v2\\lpd_image (972).xml',
#  './lpd_dataset_v2\\lpd_image (973).xml',
#  './lpd_dataset_v2\\lpd_image (974).xml',
#  './lpd_dataset_v2\\lpd_image (975).xml',
#  './lpd_dataset_v2\\lpd_image (976).xml',
#  './lpd_dataset_v2\\lpd_image (977).xml',
#  './lpd_dataset_v2\\lpd_image (978).xml',
#  './lpd_dataset_v2\\lpd_image (979).xml',
#  './lpd_dataset_v2\\lpd_image (98).xml',
#  './lpd_dataset_v2\\lpd_image (980).xml',
#  './lpd_dataset_v2\\lpd_image (981).xml',
#  './lpd_dataset_v2\\lpd_image (982).xml',
#  './lpd_dataset_v2\\lpd_image (983).xml',
#  './lpd_dataset_v2\\lpd_image (984).xml',
#  './lpd_dataset_v2\\lpd_image (985).xml',
#  './lpd_dataset_v2\\lpd_image (986).xml',
#  './lpd_dataset_v2\\lpd_image (987).xml',
#  './lpd_dataset_v2\\lpd_image (988).xml',
#  './lpd_dataset_v2\\lpd_image (989).xml',
#  './lpd_dataset_v2\\lpd_image (99).xml',
#  './lpd_dataset_v2\\lpd_image (990).xml',
#  './lpd_dataset_v2\\lpd_image (991).xml',
#  './lpd_dataset_v2\\lpd_image (992).xml',
#  './lpd_dataset_v2\\lpd_image (993).xml',
#  './lpd_dataset_v2\\lpd_image (994).xml',
#  './lpd_dataset_v2\\lpd_image (995).xml',
#  './lpd_dataset_v2\\lpd_image (996).xml',
#  './lpd_dataset_v2\\lpd_image (997).xml',
#  './lpd_dataset_v2\\lpd_image (998).xml',
#  './lpd_dataset_v2\\lpd_image (999).xml']

# %%
labels_dict = dict(filepath=[],xmin=[],xmax=[],ymin=[],ymax=[])
for filename in path:
    #filename = path[0]
    info = xet.parse(filename)
    root = info.getroot()
    member_object = root.find('object')
    labels_info = member_object.find('bndbox')
    xmin = int(labels_info.find('xmin').text)
    xmax = int(labels_info.find('xmax').text)
    ymin = int(labels_info.find('ymin').text)
    ymax = int(labels_info.find('ymax').text)
    #print(xmin,xmax,ymin,ymax)
    labels_dict['filepath'].append(filename)
    labels_dict['xmin'].append(xmin)
    labels_dict['xmax'].append(xmax)
    labels_dict['ymin'].append(ymin)
    labels_dict['ymax'].append(ymax)

# %%
df = pd.DataFrame(labels_dict)
df
# Out:
#                                   filepath  xmin  xmax  ymin  ymax
# 0       ./lpd_dataset_v2\lpd_image (1).xml    70   154   151   170
# 1      ./lpd_dataset_v2\lpd_image (10).xml   523   789   396   474
# 2     ./lpd_dataset_v2\lpd_image (100).xml   324   427   310   346
# 3    ./lpd_dataset_v2\lpd_image (1000).xml   365   600   545   616
# 4     ./lpd_dataset_v2\lpd_image (101).xml   280   608   581   677
# ..                                     ...   ...   ...   ...   ...
# 995   ./lpd_dataset_v2\lpd_image (995).xml   193   372   525   575
# 996   ./lpd_dataset_v2\lpd_image (996).xml   275   484   712   775
# 997   ./lpd_dataset_v2\lpd_image (997).xml   230   481   631   700
# 998   ./lpd_dataset_v2\lpd_image (998).xml   297   468   408   461
# 999   ./lpd_dataset_v2\lpd_image (999).xml   298   492   615   674
#
# [1000 rows x 5 columns]

# %%
df.to_csv('labels.csv',index=False)
